# %%
from matplotlib import pyplot
import numpy as np

def plotgraph(minimum,med,maximum,node,tx_rate):
    pyplot.plot(minimum,label='minimum')
    pyplot.plot(med,label='median')
    pyplot.plot(maximum,label='maximum')
    pyplot.ylabel("seconds")
    pyplot.legend()
    fig = pyplot.gcf()
    pyplot.show()
    name = "prop_"+str(node)+"_"+str(tx_rate)+".png"
    fig.savefig(name)

med = [1.8423218727111816,
 0.8199255466461182,
 3.7705860137939453,
 0.4752185344696045,
 2.263270139694214,
 1.0965666770935059,
 0.4178140163421631,
 0.6091084480285645,
 2.4563677310943604,
 1.2759408950805664,
 1.0270447731018066,
 2.6481940746307373,
 0.8501341342926025,
 1.356933832168579,
 0.670921802520752,
 2.024303674697876,
 2.6239261627197266,
 3.340338706970215,
 0.8817579746246338,
 0.8914041519165039,
 1.9636852741241455,
 0.7811157703399658,
 3.7609052658081055,
 1.3015434741973877,
 1.0365684032440186,
 0.6565752029418945,
 1.4791414737701416,
 2.02882981300354,
 1.215536117553711,
 8.549933433532715,
 1.275078296661377,
 1.4203581809997559,
 1.221914529800415]

minimum = [0.0005218982696533203,
 0.00026416778564453125,
 0.0003566741943359375,
 0.0002377033233642578,
 0.000186920166015625,
 0.00019979476928710938,
 0.00023508071899414062,
 0.0001385211944580078,
 0.00024175643920898438,
 0.0003943443298339844,
 0.00021600723266601562,
 0.0002765655517578125,
 0.00013256072998046875,
 0.00022530555725097656,
 0.0002663135528564453,
 0.00020837783813476562,
 0.0006411075592041016,
 0.0002474784851074219,
 0.0002067089080810547,
 0.0001461505889892578,
 0.0001819133758544922,
 0.0002048015594482422,
 0.00020694732666015625,
 0.00023746490478515625,
 0.00035262107849121094,
 0.0002346038818359375,
 0.0002148151397705078,
 0.00019407272338867188,
 0.0001735687255859375,
 0.00019812583923339844,
 0.0002396106719970703,
 0.00026297569274902344,
 0.0001773834228515625]

maximum = [3.3389716148376465,
 7.383373498916626,
 5.26708722114563,
 1.3054347038269043,
 3.2546567916870117,
 8.506939172744751,
 1.4283809661865234,
 1.4434497356414795,
 3.953137159347534,
 2.718618154525757,
 1.7197659015655518,
 14.293771505355835,
 1.8397514820098877,
 2.1253669261932373,
 1.3850278854370117,
 11.648353099822998,
 4.120556116104126,
 17.431243896484375,
 4.292865514755249,
 5.928876876831055,
 11.958783388137817,
 1.4146928787231445,
 5.25755500793457,
 11.728158712387085,
 2.421414375305176,
 1.251739740371704,
 6.911177396774292,
 11.283106803894043,
 2.322603702545166,
 15.49224305152893,
 1.8311936855316162,
 2.286715269088745,
 1.7643718719482422]

plotgraph(minimum,med,maximum,100,1)

# %%
from matplotlib import pyplot
bandwidth = [272589.17213,
             1628084.614656,
             4620591.22927,
             7411454.802087999,
             7783365.2928249985,
             458503.676318,
             1941694.843685,
             5268878.672925,
             7280379.479259001,
             8033564.4410919985,
             491308.875,
             2111865.191639,
             5236462.243803999,
             6975708.516116001,
             7937834.510359997
            ]
x = []
for v1 in range(20,120,20):
    for v2 in range(0,30,10):
        if v2 == 0:
            v2 = 1
        res = (v1,v2)
        res = str(res)
        x.append(res)
pyplot.plot(x,bandwidth,label="bandwidth")
pyplot.xticks(x,rotation = 'vertical')
pyplot.xlabel("bandwidth i node and j tx_rate")
pyplot.legend()
pyplot.ylabel("byte/second")
pyplot.savefig("bandwidth.png")

# %%
from matplotlib import pyplot

node_list = [99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 99, 97, 51, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]

def plot_thanos(node_list,node,tx_rate):
    pyplot.plot(node_list)
    fig = pyplot.gcf()
    pyplot.xlabel("transaction num")
    pyplot.ylabel("number of nodes reached")
    pyplot.show()
    name = "thanos_"+str(node)+"_"+str(tx_rate)+".png"
    fig.savefig(name)
plot_thanos(node_list,100,1)
